# %%
# Imports
import re
import json
import requests
import folium
import pykx as kx

# %%
conn = kx.SyncQConnection('localhost', 5114)
ships = conn('select from latest[] where destination like "FIS*",speed>=0').py()

# %%
names = [ships[x]['shipname'] for x in ships]
coords = [(ships[x]['lat'],ships[x]['lon']) for x in ships]
shipsdict = {k:v for (k,v) in zip(names,coords)}

# %%
# Create map
map = folium.Map((65.585, 22.155), zoom_start=5)
for ship in shipsdict:
        folium.Marker(location=shipsdict[ship], tooltip=ship.decode('utf-8')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5139cf82dc1ab2988d0d8eae22f1dd75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5139cf82dc1ab2988d0d8eae22f1dd75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5139cf82dc1ab2988d0d8eae22f1dd75 = L.map(
#                 &quot;map_5139cf82dc1ab2988d0d8eae22f1dd75&quot;,
#                 {
#                     center: [65.585, 22.155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d794a2ac089b93b35342ec5c8cb3231c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d794a2ac089b93b35342ec5c8cb3231c.addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             var marker_7eeab85c8c8a1e76b352a8b2ed6d144e = L.marker(
#                 [61.226252, 5.175347],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_7eeab85c8c8a1e76b352a8b2ed6d144e.bindTooltip(
#                 `&lt;div&gt;
#                      FIRDA FIGHTER
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1d147cc3f02cc9d1391d986b95f3279e = L.marker(
#                 [66.410273, 12.954362],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_1d147cc3f02cc9d1391d986b95f3279e.bindTooltip(
#                 `&lt;div&gt;
#                      NOVA HOEVDING
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_41a62616dfabe073b07f04cf20e6f970 = L.marker(
#                 [69.508723, 18.021358],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_41a62616dfabe073b07f04cf20e6f970.bindTooltip(
#                 `&lt;div&gt;
#                      FROY HILD
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a94fdab72c4d4a2cf22a7250056b064a = L.marker(
#                 [66.6615, 13.061],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_a94fdab72c4d4a2cf22a7250056b064a.bindTooltip(
#                 `&lt;div&gt;
#                      BREISUND
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_24e1850f3ac4a1eedf8ea03a8d06f994 = L.marker(
#                 [63.22896, 8.231325],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_24e1850f3ac4a1eedf8ea03a8d06f994.bindTooltip(
#                 `&lt;div&gt;
#                      BERGSOY
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b870eac6b295874f7f5c034aa24b26e1 = L.marker(
#                 [64.912835, 11.307013],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_b870eac6b295874f7f5c034aa24b26e1.bindTooltip(
#                 `&lt;div&gt;
#                      ARVID
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5021cd11eaecb118e76b0a3dfa909429 = L.marker(
#                 [63.761527, 8.673212],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_5021cd11eaecb118e76b0a3dfa909429.bindTooltip(
#                 `&lt;div&gt;
#                      ATHENA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_ca2b58318ed2aaf2c222a18f1e0549d4 = L.marker(
#                 [59.096448, 3.010185],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_ca2b58318ed2aaf2c222a18f1e0549d4.bindTooltip(
#                 `&lt;div&gt;
#                      M YTTERSTAD
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_4aad79ab95fed96bf1e545447ced07e1 = L.marker(
#                 [62.286027, 6.987365],
#                 {
# }
#             ).addTo(map_5139cf82dc1ab2988d0d8eae22f1dd75);
#
#
#             marker_4aad79ab95fed96bf1e545447ced07e1.bindTooltip(
#                 `&lt;div&gt;
#                      FROEYBLIKK
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }

# %%
conn = kx.SyncQConnection('localhost', 5114)
phist = conn('`receivets xdesc positionHist[259478000;2025.07.06D15:45;2025.07.06D16:45]').py()
coords = [(x,y) for (x,y) in zip(phist['lat'],phist['lon'])]
times = [x.isoformat() for x in phist['receivets']]
positions = {k:v for (k,v) in zip(times,coords)}
paths = [(x,y) for (x,y) in zip(coords[1:],coords[:-1])]

# %%
# Create map
map = folium.Map(coords[int(len(coords)/2)], zoom_start=16)
for p in positions: 
        folium.Marker(location=positions[p], tooltip=p, color='red').add_to(map)
for p in paths: 
        folium.PolyLine(locations=p).add_to(map)
folium.Marker(location=coords[-1], tooltip='START: '+times[-1], 
              icon=folium.Icon(icon='play', color='green')).add_to(map)
folium.Marker(location=coords[1], tooltip='FINISH: '+times[1], 
              icon=folium.Icon(icon='stop', color='red')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb7674fdcfe7ea0022ef5ad9964c983a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb7674fdcfe7ea0022ef5ad9964c983a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb7674fdcfe7ea0022ef5ad9964c983a = L.map(
#                 &quot;map_eb7674fdcfe7ea0022ef5ad9964c983a&quot;,
#                 {
#                     center: [71.073113, 28.724183],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 16,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59598acb9db83b36dc4f15c3e7dff026 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59598acb9db83b36dc4f15c3e7dff026.addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             var marker_73355ba7942c0256d658bc496c34b07b = L.marker(
#                 [71.070867, 28.722037],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_73355ba7942c0256d658bc496c34b07b.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:22:53.565220
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_b766c14aff40d564205daf25c298b817 = L.marker(
#                 [71.07124, 28.722777],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_b766c14aff40d564205daf25c298b817.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:20:53.354205
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fccd3bdbff2c9fdc637f40140a0abd8d = L.marker(
#                 [71.071893, 28.72382],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_fccd3bdbff2c9fdc637f40140a0abd8d.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:18:50.159198
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_57de10a728a728889bc5c99a4eba5d8f = L.marker(
#                 [71.072027, 28.724893],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_57de10a728a728889bc5c99a4eba5d8f.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:16:47.301494
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0ab36da44c0ac01c788cbf1bd15720c3 = L.marker(
#                 [71.072227, 28.725787],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_0ab36da44c0ac01c788cbf1bd15720c3.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:14:44.103425
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7b17a7bcf68530cafbd068f73d5532c2 = L.marker(
#                 [71.07246, 28.72776],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_7b17a7bcf68530cafbd068f73d5532c2.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:12:43.447978
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_55cae9301b2476113a5e63a9b3782b62 = L.marker(
#                 [71.07292, 28.72803],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_55cae9301b2476113a5e63a9b3782b62.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:10:39.878988
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_efeb171c76348d73c93bf8ea76c57a6b = L.marker(
#                 [71.072707, 28.725713],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_eb7674fdcfe7ea0022ef5ad9964c983a);
#
#
#             marker_efeb171c76348d73c93bf8ea76c57a6b.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-06T16:08:40.709070
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: t
