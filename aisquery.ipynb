# %%
# Imports
import re
import json
import requests
import folium
import pykx as kx

# %%
conn = kx.SyncQConnection('localhost', 5114)
ships = conn('select from latest[] where destination like "FIS*",speed>=0').py()

# %%
names = [ships[x]['shipname'] for x in ships]
coords = [(ships[x]['lat'],ships[x]['lon']) for x in ships]
shipsdict = {k:v for (k,v) in zip(names,coords)}

# %%
# Create map
map = folium.Map((65.585, 22.155), zoom_start=5)
for ship in shipsdict:
        folium.Marker(location=shipsdict[ship], tooltip=ship.decode('utf-8')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21c818bfb12417fb23c001534ad9b599 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21c818bfb12417fb23c001534ad9b599&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_21c818bfb12417fb23c001534ad9b599 = L.map(
#                 &quot;map_21c818bfb12417fb23c001534ad9b599&quot;,
#                 {
#                     center: [65.585, 22.155],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f82fff0ebf553730ba6643d2e69c7d7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f82fff0ebf553730ba6643d2e69c7d7d.addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             var marker_7ddc244c1a1a31c48d481476c8b9cea4 = L.marker(
#                 [61.22626, 5.175342],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_7ddc244c1a1a31c48d481476c8b9cea4.bindTooltip(
#                 `&lt;div&gt;
#                      FIRDA FIGHTER
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c736848e731e6adacded68fdfd019c65 = L.marker(
#                 [66.410273, 12.954373],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_c736848e731e6adacded68fdfd019c65.bindTooltip(
#                 `&lt;div&gt;
#                      NOVA HOEVDING
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_52963fafe7b5efb789fbbabf550144c0 = L.marker(
#                 [69.510272, 18.02015],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_52963fafe7b5efb789fbbabf550144c0.bindTooltip(
#                 `&lt;div&gt;
#                      FROY HILD
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_727f6d356f9923ea57031ae7899955fc = L.marker(
#                 [66.6615, 13.060833],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_727f6d356f9923ea57031ae7899955fc.bindTooltip(
#                 `&lt;div&gt;
#                      BREISUND
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_26e1203911d701fa32ea68d1a943e721 = L.marker(
#                 [63.228972, 8.231362],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_26e1203911d701fa32ea68d1a943e721.bindTooltip(
#                 `&lt;div&gt;
#                      BERGSOY
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fb7d24866888946f7c9c9eae0fd6adad = L.marker(
#                 [64.912838, 11.307028],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_fb7d24866888946f7c9c9eae0fd6adad.bindTooltip(
#                 `&lt;div&gt;
#                      ARVID
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_9aedc4e1d3c35d2464176614d245c5f0 = L.marker(
#                 [63.761527, 8.673237],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_9aedc4e1d3c35d2464176614d245c5f0.bindTooltip(
#                 `&lt;div&gt;
#                      ATHENA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_1c8c562745af76f0eab14ef41fae8e00 = L.marker(
#                 [59.016018, 2.988482],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_1c8c562745af76f0eab14ef41fae8e00.bindTooltip(
#                 `&lt;div&gt;
#                      M YTTERSTAD
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_21f2b12fc0256fe8ecda589c17d5300b = L.marker(
#                 [62.286033, 6.987345],
#                 {
# }
#             ).addTo(map_21c818bfb12417fb23c001534ad9b599);
#
#
#             marker_21f2b12fc0256fe8ecda589c17d5300b.bindTooltip(
#                 `&lt;div&gt;
#                      FROEYBLIKK
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }

# %%
conn = kx.SyncQConnection('localhost', 5114)
phist = conn('`receivets xdesc positionHist[257003340;2025.07.07D0;2025.07.08D0]').py()
coords = [(x,y) for (x,y) in zip(phist['lat'],phist['lon'])]
times = [x.isoformat() for x in phist['receivets']]
positions = {k:v for (k,v) in zip(times,coords)}
paths = [(x,y) for (x,y) in zip(coords[1:],coords[:-1])]

# %%
# Create map
map = folium.Map(coords[int(len(coords)/2)], zoom_start=13)
for p in positions: 
        folium.Marker(location=positions[p], tooltip=p, color='red').add_to(map)
for p in paths: 
        folium.PolyLine(locations=p).add_to(map)
folium.Marker(location=coords[-1], tooltip='START: '+times[-1], 
              icon=folium.Icon(icon='play', color='green')).add_to(map)
folium.Marker(location=coords[1], tooltip='FINISH: '+times[1], 
              icon=folium.Icon(icon='stop', color='red')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0dd2dff1476263edbeba586644a6fa6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0dd2dff1476263edbeba586644a6fa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0dd2dff1476263edbeba586644a6fa6 = L.map(
#                 &quot;map_e0dd2dff1476263edbeba586644a6fa6&quot;,
#                 {
#                     center: [67.438547, 13.961213],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afb8e220c113a12c2ae4033aa8e650f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afb8e220c113a12c2ae4033aa8e650f4.addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             var marker_ad90e058a44a3ab1349b81b00767efcf = L.marker(
#                 [67.384073, 13.874363],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_ad90e058a44a3ab1349b81b00767efcf.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:54:57.444402
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5fdf04f06a3f0d8e78d00d49cfb0488b = L.marker(
#                 [67.384247, 13.86461],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_5fdf04f06a3f0d8e78d00d49cfb0488b.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:52:48.307146
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_a9fbbad018820adc98a0138df61a276f = L.marker(
#                 [67.384373, 13.854423],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_a9fbbad018820adc98a0138df61a276f.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:50:39.004603
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_c29f34010d91b6c4dd61e205f7462b91 = L.marker(
#                 [67.384547, 13.845225],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_c29f34010d91b6c4dd61e205f7462b91.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:48:39.359055
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_99181938a384447ce216c21f81d9df09 = L.marker(
#                 [67.386827, 13.841912],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_99181938a384447ce216c21f81d9df09.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:46:39.141465
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2ad7032d2334b93a401afd6af8897756 = L.marker(
#                 [67.387093, 13.838403],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_2ad7032d2334b93a401afd6af8897756.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:44:39.725293
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_dbdceecc22fcd5b7f8b30c30a768b575 = L.marker(
#                 [67.386607, 13.830833],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_dbdceecc22fcd5b7f8b30c30a768b575.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:42:39.020916
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3db1fa93e13a15cdcfda7f9781f15d69 = L.marker(
#                 [67.38716, 13.821962],
#                 {
#   &quot;color&quot;: &quot;red&quot;,
# }
#             ).addTo(map_e0dd2dff1476263edbeba586644a6fa6);
#
#
#             marker_3db1fa93e13a15cdcfda7f9781f15d69.bindTooltip(
#                 `&lt;div&gt;
#                      2025-07-07T01:40:37.491796
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot
